# %% [markdown]
# <a href="https://colab.research.google.com/github/XenoHead/AudioBooks/blob/main/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook Google Colab!
# ## Features
# - 🔧 **TTS Engines supported**: XTTSv2, Bark, Fairseq, VITS, Tacotron2, Tortoise, GlowTTS, YourTTS- 📚 **Convert multiple file formats**: .epub, .mobi, .azw3, .fb2, .lrf, .rb, .snb, .tcr, .pdf, .txt, .rtf, .doc, .docx, .html, .odt, .azw, .tiff, .tif, .png, .jpg, .jpeg, .bmp
# - 🔍 **OCR scanning** for files with text pages as images
# - 🔊 **High-quality text-to-speech** from near realtime to near real voice
# - 🗣️ **Optional voice cloning** using your own voice file
# - 🌐 **Supports 1158 languages** ([supported languages list](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html))
# - 💻 **Low-resource friendly** — runs on **2 GB RAM / 1 GB VRAM (minimum)**
# - 🎵 **Audiobook output formats**: mono or stereo aac, flac, mp3, m4b, m4a, mp4, mov, ogg, wav, webm
# - 🧠 **SML tags supported** — fine-grained control of breaks, pauses, voice switching and more ([see below](#sml-tags-available))
# - 🧩 **Optional custom model** using your own trained model (XTTSv2 only, other on request)
# - 🎛️ **Fine-tuned preset models** trained by the E2A Team<br/>
#      <i>(Contact us if you need additional fine-tuned models, or if you'd like to share yours to the official preset list)</i>
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🚀 Run ebook2audiobook!

import os
import subprocess
import time
import shutil
import sysconfig

# Emojis for logs
CHECK_MARK = "✅"
CROSS_MARK = "❌"

SCRIPT_DIR = "/content/ebook2audiobook"

# ── Environment variables (mirrors the bash script) ──────────────────────────
os.environ["PYTHONUTF8"]        = "1"
os.environ["PYTHONIOENCODING"]  = "utf-8"
os.environ["TTS_CACHE"]         = f"{SCRIPT_DIR}/models"
os.environ["TESSDATA_PREFIX"]   = f"{SCRIPT_DIR}/models/tessdata"
os.environ["TMPDIR"]            = f"{SCRIPT_DIR}/tmp"

def display_loading_bar(total_steps):
    print("\n---  LOADING...  Total steps:", total_steps, " ---")

def update_progress(step, total_steps):
    bar_length = 20
    progress_percent = int((step / total_steps) * 100)
    progress_filled = int(bar_length * step / total_steps)
    bar = '=' * progress_filled + '>' + ' ' * max(bar_length - progress_filled - 1, 0)
    print(f"---  PROGRESS:  [{bar}] {progress_percent}% ({step}/{total_steps}) ---")

def run_command_with_log(command, description, step_progress, total_step_commands):
    """Runs a shell command and logs progress, outcome and duration."""
    print(f"\n{step_progress}/{total_step_commands}: {description}...")
    start_time = time.time()
    try:
        process = subprocess.Popen(command, shell=True,
                                   stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        stdout, stderr = process.communicate()
        duration = f"{time.time() - start_time:.2f}"
        if process.returncode != 0:
            print(f"{CROSS_MARK} Command failed: {description} (Took {duration}s)")
            print(f"   Command: {command}")
            print(f"   Error Output:\n{stderr.decode()}")
            return False
        else:
            update_progress(step_progress, total_step_commands)
            print(f"{CHECK_MARK} {step_progress}/{total_step_commands} completed: {description} (Took {duration}s)")
            return True
    except Exception as e:
        duration = f"{time.time() - start_time:.2f}"
        print(f"{CROSS_MARK} Error during: {description} (Took {duration}s) — {e}")
        return False


# ── Step 1 : OS-level packages ────────────────────────────────────────────────
# Mirrors HOST_PROGRAMS from the bash script + Calibre's special installer
os_install_commands = [
    ("apt-get update -qq",
     "Update package lists"),
    ("apt-get install -y -qq libxcb-cursor0 libegl1 libopengl0",
     "Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0)"),
    ("sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin",
     "Download & install Calibre"),
    ("apt-get install -y -qq ffmpeg",
     "Install ffmpeg"),
    ("apt-get install -y -qq mediainfo",
     "Install mediainfo"),
    ("apt-get install -y -qq nodejs",
     "Install nodejs"),
    ("apt-get install -y -qq espeak-ng",
     "Install espeak-ng"),
    ("apt-get install -y -qq sox",
     "Install sox"),
    ("apt-get install -y -qq tesseract-ocr tesseract-ocr-eng",
     "Install Tesseract OCR + English language pack"),
    # mecab + unidic (for Japanese support, same as old notebook)
    ("apt-get install -y -qq mecab libmecab-dev mecab-ipadic-utf8",
     "Install mecab (Japanese text analysis)"),
    # Rust is required by some pip packages (e.g. tokenizers)
    ("curl -fsSL https://sh.rustup.rs | sh -s -- -y --quiet && "
     "echo 'source $HOME/.cargo/env' >> ~/.bashrc",
     "Install Rust (required by some Python packages)"),
]

# ── Step 2 : Git clone ────────────────────────────────────────────────────────
git_commands = [
    ("git clone --depth=1 https://github.com/DrewThomasson/ebook2audiobook.git /content/ebook2audiobook",
     "Git clone ebook2audiobook"),
]

# ── Step 3 : Python packages  (mirrors install_python_packages()) ─────────────
# llvmlite/numba must be installed first as pre-built binaries;
# then the rest of requirements.txt is installed line-by-line.
# unidic download closes out the step.
pip_commands = [
    ("pip install -q --upgrade pip setuptools wheel",
     "Upgrade pip / setuptools / wheel"),
    ("pip install -q --upgrade llvmlite numba --only-binary=:all:",
     "Install llvmlite & numba (pre-built binaries only)"),
    ("pip install -q --upgrade --no-cache-dir "
     "-r /content/ebook2audiobook/requirements.txt",
     "Install Python requirements from requirements.txt"),
    ("python -m unidic download",
     "Download Unidic dictionary data"),
]


# ── Helper: sitecustomize hook (mirrors check_sitecustomized()) ───────────────
def install_sitecustomize():
    src = f"{SCRIPT_DIR}/components/sitecustomize.py"
    dst_dir = sysconfig.get_paths()["purelib"]
    dst = os.path.join(dst_dir, "sitecustomize.py")
    if not os.path.exists(src):
        print(f"{CROSS_MARK} sitecustomize.py source not found at {src}, skipping.")
        return False
    if not os.path.exists(dst) or os.path.getmtime(src) > os.path.getmtime(dst):
        shutil.copy2(src, dst)
        print(f"{CHECK_MARK} Installed sitecustomize.py hook → {dst}")
    else:
        print(f"{CHECK_MARK} sitecustomize.py already up-to-date.")
    return True


# ════════════════════════════════════════════════════════════════════════════
# EXECUTION
# ════════════════════════════════════════════════════════════════════════════

# --- Step 1: OS packages ---
print("\n--- Step 1: OS-Level Installations ---")
print("Installs system packages required by the bash script. (~3-5 min)")
display_loading_bar(len(os_install_commands))
step1_ok = True
for i, (cmd, desc) in enumerate(os_install_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(os_install_commands)):
        step1_ok = False
        break

# Activate Rust for the current session after installation
cargo_env = os.path.expanduser("~/.cargo/env")
if os.path.exists(cargo_env):
    os.environ["PATH"] = os.path.expanduser("~/.cargo/bin") + ":" + os.environ.get("PATH", "")

if step1_ok:
    print(f"\n{CHECK_MARK} Step 1: OS-Level Installations — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 1: OS-Level Installations — Failed. See errors above.")


# --- Step 2: Git Clone ---
print("\n--- Step 2: Git Clone ---")
display_loading_bar(len(git_commands))
step2_ok = True
for i, (cmd, desc) in enumerate(git_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(git_commands)):
        step2_ok = False
        break

if step2_ok:
    print(f"\n{CHECK_MARK} Step 2: Git Clone — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 2: Git Clone — Failed. See errors above.")


# --- Step 3: Python packages ---
print("\n--- Step 3: Python Package Installation ---")
print("Mirrors install_python_packages() from the bash script. (~3-5 min)")
display_loading_bar(len(pip_commands))
step3_ok = True
for i, (cmd, desc) in enumerate(pip_commands):
    if not run_command_with_log(cmd, desc, i + 1, len(pip_commands)):
        step3_ok = False
        break

if step3_ok:
    print(f"\n{CHECK_MARK} Step 3: Python Package Installation — Completed Successfully!")
else:
    print(f"\n{CROSS_MARK} Step 3: Python Package Installation — Failed. See errors above.")


# --- Step 4: sitecustomize hook ---
print("\n--- Step 4: Installing sitecustomize.py hook ---")
install_sitecustomize()


# --- Step 5: Create required directories ---
print("\n--- Step 5: Creating required directories ---")
for d in ["models", "models/tessdata", "tmp", "run", "audiobooks", "ebooks", "voices"]:
    os.makedirs(f"{SCRIPT_DIR}/{d}", exist_ok=True)
os.chmod(f"{SCRIPT_DIR}/tmp", 0o777)
print(f"{CHECK_MARK} Directories ready.")


# --- Step 6: Run App ---
print("\n--- Step 6: Launch ebook2audiobook ---")
print("Starting the Gradio web interface with a public share link...")
try:
    # script_mode=native matches the NATIVE branch of the bash script;
    # --share creates the public Gradio tunnel link.
    get_ipython().system(
        "cd /content/ebook2audiobook && "
        "python -u app.py --script_mode native --share"
    )
except Exception as e:
    print(f"{CROSS_MARK} Error starting app.py: {e}")

print("\n--- All Steps Completed ---")
print("Check the output above for the public Gradio URL.")
# Out:
# --- Step 1: OS-Level Installations ---
# Installs system packages required by the bash script. (~3-5 min)
#
# ---  LOADING...  Total steps: 11  ---
#
# 1/11: Update package lists...
# ---  PROGRESS:  [=>                  ] 9% (1/11) ---
# ✅ 1/11 completed: Update package lists (Took 7.60s)
#
# 2/11: Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0)...
# ---  PROGRESS:  [===>                ] 18% (2/11) ---
# ✅ 2/11 completed: Install Calibre display libraries (libxcb-cursor0, libegl1, libopengl0) (Took 8.91s)
#
# 3/11: Download & install Calibre...
# ---  PROGRESS:  [=====>              ] 27% (3/11) ---
# ✅ 3/11 completed: Download & install Calibre (Took 45.52s)
#
# 4/11: Install ffmpeg...
# ---  PROGRESS:  [=======>            ] 36% (4/11) ---
# ✅ 4/11 completed: Install ffmpeg (Took 2.60s)
#
# 5/11: Install mediainfo...
# ---  PROGRESS:  [=========>          ] 45% (5/11) ---
# ✅ 5/11 completed: Install mediainfo (Took 6.16s)
#
# 6/11: Install nodejs...
# ---  PROGRESS:  [==========>         ] 54% (6/11) ---
# ✅ 6/11 completed: Install nodejs (Took 6.87s)
#
# 7/11: Install espeak-ng...
# ---  PROGRESS:  [============>       ] 63% (7/11) ---
# ✅ 7/11 completed: Install espeak-ng (Took 5.55s)
#
# 8/11: Install sox...
# ---  PROGRESS:  [==============>     ] 72% (8/11) ---
# ✅ 8/11 completed: Install sox (Took 6.80s)
#
# 9/11: Install Tesseract OCR + English language pack...
# ---  PROGRESS:  [================>   ] 81% (9/11) ---
# ✅ 9/11 completed: Install Tesseract OCR + English language pack (Took 2.59s)
#
# 10/11: Install mecab (Japanese text analysis)...
# ---  PROGRESS:  [==================> ] 90% (10/11) ---
# ✅ 10/11 completed: Install mecab (Japanese text analysis) (Took 11.53s)
#
# 11/11: Install Rust (required by some Python packages)...
# ❌ Command failed: Install Rust (required by some Python packages) (Took 0.15s)
#    Command: curl -fsSL https://sh.rustup.rs | sh -s -- -y --quiet && echo 'source $HOME/.cargo/env' >> ~/.bashrc
#    Error Output:
# mktemp: failed to create directory via template ‘/content/ebook2audiobook/tmp/tmp.XXXXXXXXXX’: No such file or directory
# error: command failed: mktemp -d
#
#
# ❌ Step 1: OS-Level Installations — Failed. See errors above.
#
# --- Step 2: Git Clone ---
#
# ---  LOADING...  Total steps: 1  ---
#
# 1/1: Git clone ebook2audiobook...
# ---  PROGRESS:  [====================>] 100% (1/1) ---
# ✅ 1/1 completed: Git clone ebook2audiobook (Took 16.11s)
#
# ✅ Step 2: Git Clone — Completed Successfully!
#
# --- Step 3: Python Package Installation ---
# Mirrors install_python_packages() from the bash script. (~3-5 min)
#
# ---  LOADING...  Total steps: 4  ---
#
# 1/4: Upgrade pip / setuptools / wheel...
# ---  PROGRESS:  [=====>              ] 25% (1/4) ---
# ✅ 1/4 completed: Upgrade pip / setuptools / wheel (Took 11.87s)
#
# 2/4: Install llvmlite & numba (pre-built binaries only)...
# ---  PROGRESS:  [==========>         ] 50% (2/4) ---
# ✅ 2/4 completed: Install llvmlite & numba (pre-built binaries only) (Took 8.73s)
#
# 3/4: Install Python requirements from requirements.txt...
# ❌ Command failed: Install Python requirements from requirements.txt (Took 0.54s)
#    Command: pip install -q --upgrade --no-cache-dir -r /content/ebook2audiobook/requirements.txt
#    Error Output:
# ERROR: Invalid requirement: './ext/py/demucs': Expected package name at the start of dependency specifier
#     ./ext/py/demucs
#     ^ (from line 58 of /content/ebook2audiobook/requirements.txt)
# Hint: It looks like a path. File './ext/py/demucs' does not exist.
#
#
# ❌ Step 3: Python Package Installation — Failed. See errors above.
#
# --- Step 4: Installing sitecustomize.py hook ---
# ✅ Installed sitecustomize.py hook → /usr/local/lib/python3.12/dist-packages/sitecustomize.py
#
# --- Step 5: Creating required directories ---
# ✅ Directories ready.
#
# --- Step 6: Launch ebook2audiobook ---
# Starting the Gradio web interface with a public share link...
# v26.5.20 native mode
# ---> Hardware detected: {'name': 'cuda', 'os': 'manylinux_2_28', 'arch': 'x86_64', 'pyvenv': [3, 12], 'tag': 'cu128', 'note': ''}
# Installing the right library packages for cuda…
# Collecting filelock
#   Downloading filelock-3.29.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting sympy
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting MarkupSafe>=2.0 (from jinja2)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading filelock-3.29.3-py3-none-any.whl (42 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 447.8 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 309.8 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 787.0 MB/s  0:00:00
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Installing collected packages: mpmath, sympy, networkx, MarkupSafe, fsspec, filelock, jinja2
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.29.1
#     Uninstalling filelock-3.29.1:
#       Successfully uninstalled filelock-3.29.1
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [jinja2]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.4.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.4.0 which is incompatible.
# torch 2.11.0+cu128 requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-3.29.3 fsspec-2026.4.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 sympy-1.14.0
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Collecting torch==2.9.0
#   Downloading torch-2.9.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchaudio==2.9.0
#   Downloading torchaudio-2.9.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Collecting filelock (from torch==2.9.0)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting typing-extensions>=4.10.0 (from torch==2.9.0)
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting setuptools (from torch==2.9.0)
#   Downloading setuptools-70.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting sympy>=1.13.3 (from torch==2.9.0)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch==2.9.0)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting jinja2 (from torch==2.9.0)
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec>=0.8.5 (from torch==2.9.0)
#   Downloading fsspec-2026.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch==2.9.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 495.9 MB/s  0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch==2.9.0)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 636.9 MB/s  0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch==2.9.0)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 491.4 MB/s  0:00:00
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch==2.9.0)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 389.8 MB/s  0:00:03
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch==2.9.0)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 92.3 MB/s  0:00:03
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch==2.9.0)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 326.6 MB/s  0:00:00
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch==2.9.0)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 513.2 MB/s  0:00:00
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch==2.9.0)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 78.3 MB/s  0:00:03
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch==2.9.0)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 340.2 MB/s  0:00:00
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch==2.9.0)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 288.4 MB/s  0:00:00
# Collecting nvidia-nccl-cu12==2.27.5 (from torch==2.9.0)
#   Downloading nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.3/322.3 MB 71.1 MB/s  0:00:03
# Collecting nvidia-nvshmem-cu12==3.3.20 (from torch==2.9.0)
#   Downloading nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.7/124.7 MB 356.3 MB/s  0:00:00
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch==2.9.0)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch==2.9.0)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 494.9 MB/s  0:00:00
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch==2.9.0)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 683.0 MB/s  0:00:00
# Collecting triton==3.5.0 (from torch==2.9.0)
#   Downloading triton-3.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch==2.9.0)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.9.0)
#   Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Downloading torch-2.9.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (900.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 900.9/900.9 MB 210.7 MB/s  0:00:03
# Downloading torchaudio-2.9.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 379.0 MB/s  0:00:00
# Downloading triton-3.5.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.5/170.5 MB 255.5 MB/s  0:00:00
# Downloading fsspec-2026.4.0-py3-none-any.whl (203 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.8 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 68.7 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 238.7 MB/s  0:00:00
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading setuptools-70.2.0-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.8/930.8 kB 366.1 MB/s  0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, typing-extensions, triton, sympy, setuptools, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, MarkupSafe, fsspec, filelock, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchaudio
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.7.1
#     Uninstalling nvidia-cusparselt-cu12-0.7.1:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.7.1
#   Attempting uninstall: mpmath
#     Found existing installation: mpmath 1.3.0
#     Uninstalling mpmath-1.3.0:
#       Successfully uninstalled mpmath-1.3.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
#   Attempting uninstall: triton
#     Found existing installation: triton 3.6.0
#     Uninstalling triton-3.6.0:
#       Successfully uninstalled triton-3.6.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 82.0.1
#     Uninstalling setuptools-82.0.1:
#       Successfully uninstalled setuptools-82.0.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.8.90
#     Uninstalling nvidia-nvtx-cu12-12.8.90:
#       Successfully uninstalled nvidia-nvtx-cu12-12.8.90
#   Attempting uninstall: nvidia-nvshmem-cu12
#     Found existing installation: nvidia-nvshmem-cu12 3.4.5
#     Uninstalling nvidia-nvshmem-cu12-3.4.5:
#       Successfully uninstalled nvidia-nvshmem-cu12-3.4.5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.8.93
#     Uninstalling nvidia-nvjitlink-cu12-12.8.93:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.8.93
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.28.9
#     Uninstalling nvidia-nccl-cu12-2.28.9:
#       Successfully uninstalled nvidia-nccl-cu12-2.28.9
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.9.90
#     Uninstalling nvidia-curand-cu12-10.3.9.90:
#       Successfully uninstalled nvidia-curand-cu12-10.3.9.90
#   Attempting uninstall: nvidia-cufile-cu12
#     Found existing installation: nvidia-cufile-cu12 1.13.1.3
#     Uninstalling nvidia-cufile-cu12-1.13.1.3:
#       Successfully uninstalled nvidia-cufile-cu12-1.13.1.3
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.8.90
#     Uninstalling nvidia-cuda-runtime-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.8.90
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.8.93
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.8.93:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.8.93
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.8.90
#     Uninstalling nvidia-cuda-cupti-cu12-12.8.90:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.8.90
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.8.4.1
#     Uninstalling nvidia-cublas-cu12-12.8.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.8.4.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.3
#     Uninstalling MarkupSafe-3.0.3:
#       Successfully uninstalled MarkupSafe-3.0.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2026.4.0
#     Uninstalling fsspec-2026.4.0:
#       Successfully uninstalled fsspec-2026.4.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.29.3
#     Uninstalling filelock-3.29.3:
#       Successfully uninstalled filelock-3.29.3
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.8.93
#     Uninstalling nvidia-cusparse-cu12-12.5.8.93:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.8.93
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.3.83
#     Uninstalling nvidia-cufft-cu12-11.3.3.83:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.19.0.56
#     Uninstalling nvidia-cudnn-cu12-9.19.0.56:
#       Successfully uninstalled nvidia-cudnn-cu12-9.19.0.56
#   Attempting uninstall: jinja2
#     Found existing installation: Jinja2 3.1.6
#     Uninstalling Jinja2-3.1.6:
#       Successfully uninstalled Jinja2-3.1.6
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.3.90
#     Uninstalling nvidia-cusolver-cu12-11.7.3.90:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.3.90
#   Attempting uninstall: torch
#     Found existing installation: torch 2.11.0+cu128
#     Uninstalling torch-2.11.0+cu128:
#       Successfully uninstalled torch-2.11.0+cu128
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.11.0+cu128
#     Uninstalling torchaudio-2.11.0+cu128:
#       Successfully uninstalled torchaudio-2.11.0+cu128
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [torchaudio]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torchvision 0.26.0+cu128 requires torch==2.11.0, but you have torch 2.9.0+cu128 which is incompatible.
# datasets 4.0.0 requires fsspec[http]<=2025.3.0,>=2023.1.0, but you have fsspec 2026.4.0 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2026.4.0 which is incompatible.
# cudf-cu12 26.2.1 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# cuml-cu12 26.2.0 requires numba<0.62.0,>=0.60.0, but you have numba 0.65.1 which is incompatible.
# Successfully installed MarkupSafe-3.0.3 filelock-3.29.0 fsspec-2026.4.0 jinja2-3.1.6 mpmath-1.3.0 networkx-3.6.1 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 setuptools-70.2.0 sympy-1.14.0 torch-2.9.0+cu128 torchaudio-2.9.0+cu128 triton-3.5.0 typing-extensions-4.15.0
# Looking in indexes: https://download.pytorch.org/whl/cu128
# Collecting torchcodec==0.7.0
#   Downloading torchcodec-0.7.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.4 kB)
# Downloading torchcodec-0.7.0%2Bcu128-cp312-cp312-manylinux_2_28_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 202.8 MB/s  0:00:00
# Installing collected packages: torchcodec
#   Attempting uninstall: torchcodec
#     Found existing installation: torchcodec 0.11.0+cu128
#     Uninstalling torchcodec-0.11.0+cu128:
#       Successfully uninstalled torchcodec-0.11.0+cu128
# Successfully installed torchcodec-0.7.0+cu128
# docker is not installed.
# ebooklib is not installed.
# python-pptx is not installed.
# python-docx is not installed.
# lameenc is not installed.
# museval is not installed.
# openunmix is not installed.
# submitit is not installed.
# treetable is not installed.
# dora-search is not installed.
# nagisa is not installed.
# pymupdf is not installed.
# pymupdf-layout is not installed.
# unidic is not installed.
# hangul-romanize is not installed.
# iso639-lang is not installed.
# soynlp is not installed.
# uroman is not installed.
# pycantonese is not installed.
# pypinyin is not installed.
# pythainlp is not installed.
# pykakasi is not installed.
# mutagen is not installed.
# phonemizer-fork is not installed.
# num2words2 is not installed.
# unidecode is not installed.
# langdetect is not installed.
# phonemizer is not installed.
# indic-nlp-library is not installed.
# pytesseract is not installed.
# torchvggish is not installed.
# stanza is not installed.
# argostranslate is not installed.
# gradio (installed 5.50.0) != required 5.49.1.
# onnxruntime-gpu is not installed.
# pyannote-audio is not installed.
# coqui-tts is not installed.
# piper-tts is not installed.
# demucs is not installed.
#
# Installing missing or upgrade packages…
#
# WARNING: No matching packages
# Files removed: 0 (0 bytes)
# Directories removed: 0
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (26.1.2)
# Collecting docker
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from docker) (2.32.4)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from docker) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (3.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->docker) (2026.5.20)
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Installing collected packages: docker
# Successfully installed docker-7.1.0
# Collecting ebooklib
#   Downloading ebooklib-0.20-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from ebooklib) (6.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ebooklib) (1.17.0)
# Downloading ebooklib-0.20-py3-none-any.whl (40 kB)
# Installing collected packages: ebooklib
# Successfully installed ebooklib-0.20
# Collecting python-pptx
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (11.3.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading xlsxwriter-3.2.9-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (6.1.1)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-pptx) (4.15.0)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading xlsxwriter-3.2.9-py3-none-any.whl (175 kB)
# Installing collected packages: XlsxWriter, python-pptx
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [python-pptx]
# Successfully installed XlsxWriter-3.2.9 python-pptx-1.0.2
# Collecting python-docx
#   Downloading python_docx-1.2.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (6.1.1)
# Requirement already satisfied: typing_extensions>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from python-docx) (4.15.0)
# Downloading python_docx-1.2.0-py3-none-any.whl (252 kB)
# Installing collected packages: python-docx
# Successfully installed python-docx-1.2.0
# Collecting lameenc
#   Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10.0 kB)
# Downloading lameenc-1.8.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (249 kB)
# Installing collected packages: lameenc
# Successfully installed lameenc-1.8.2
# Collecting museval
#   Downloading museval-0.4.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting musdb>=0.4.0 (from museval)
#   Downloading musdb-0.4.3-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from museval) (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from museval) (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from museval) (1.16.3)
# Requirement already satisfied: simplejson>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from museval) (4.1.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from museval) (0.13.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from museval) (4.26.0)
# Collecting stempeg>=0.2.4 (from musdb>=0.4.0->museval)
#   Downloading stempeg-0.2.6-py3-none-any.whl.metadata (9.2 kB)
# Collecting pyaml (from musdb>=0.4.0->museval)
#   Downloading pyaml-26.2.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from musdb>=0.4.0->museval) (4.67.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->museval) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->museval) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0.1->museval) (2026.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->museval) (1.17.0)
# Collecting ffmpeg-python>=0.2.0 (from stempeg>=0.2.4->musdb>=0.4.0->museval)
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from ffmpeg-python>=0.2.0->stempeg>=0.2.4->musdb>=0.4.0->museval) (1.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->museval) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->museval) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema->museval) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->museval) (2026.5.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from referencing>=0.28.4->jsonschema->museval) (4.15.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from pyaml->musdb>=0.4.0->museval) (6.0.3)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->museval) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->museval) (3.0)
# Downloading museval-0.4.1-py2.py3-none-any.whl (20 kB)
# Downloading musdb-0.4.3-py2.py3-none-any.whl (13 kB)
# Downloading stempeg-0.2.6-py3-none-any.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.2/963.2 kB 85.8 MB/s  0:00:00
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading pyaml-26.2.1-py3-none-any.whl (27 kB)
# Installing collected packages: pyaml, ffmpeg-python, stempeg, musdb, museval
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [museval]
# Successfully installed ffmpeg-python-0.2.0 musdb-0.4.3 museval-0.4.1 pyaml-26.2.1 stempeg-0.2.6
# Collecting openunmix
#   Downloading openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openunmix) (2.0.2)
# Requirement already satisfied: torchaudio>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from openunmix) (2.9.0+cu128)
# Requirement already satisfied: torch>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openunmix) (2.9.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from openunmix) (4.67.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9.0->openunmix) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9.0->openunmix) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9.0->openunmix) (3.0.3)
# Downloading openunmix-1.3.0-py3-none-any.whl (40 kB)
# Installing collected packages: openunmix
# Successfully installed openunmix-1.3.0
# Collecting submitit
#   Downloading submitit-1.5.4-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit) (3.1.2)
# Requirement already satisfied: typing_extensions>=3.7.4.2 in /usr/local/lib/python3.12/dist-packages (from submitit) (4.15.0)
# Downloading submitit-1.5.4-py3-none-any.whl (76 kB)
# Installing collected packages: submitit
# Successfully installed submitit-1.5.4
# Collecting treetable
#   Downloading treetable-0.2.6-py3-none-any.whl.metadata (5.3 kB)
# Downloading treetable-0.2.6-py3-none-any.whl (7.4 kB)
# Installing collected packages: treetable
# Successfully installed treetable-0.2.6
# Collecting dora-search
#   Downloading dora_search-0.1.12.tar.gz (87 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search) (2.3.0)
# Collecting retrying (from dora-search)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: submitit in /usr/local/lib/python3.12/dist-packages (from dora-search) (1.5.4)
# Requirement already satisfied: treetable in /usr/local/lib/python3.12/dist-packages (from dora-search) (0.2.6)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from dora-search) (2.9.0+cu128)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search) (6.0.3)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search) (3.1.2)
# Requirement already satisfied: typing_extensions>=3.7.4.2 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (3.29.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->dora-search) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->dora-search) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->dora-search) (3.0.3)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Building wheels for collected packages: dora-search
#   Building wheel for dora-search (pyproject.toml) ... done
#   Created wheel for dora-search: filename=dora_search-0.1.12-py3-none-any.whl size=75195 sha256=8fdcaf8028939c84051f5f0763f1d195b1e2ebc85f47d8bde99f0e7af65a5c4c
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-osu08aa5/wheels/55/40/4c/3478187386b56625ab5aa8a9070ff1eea704ddb27d15abe73f
# Successfully built dora-search
# Installing collected packages: retrying, dora-search
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [dora-search]
# Successfully installed dora-search-0.1.12 retrying-1.4.2
# Collecting nagisa
#   Downloading nagisa-0.2.12-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from nagisa) (1.17.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from nagisa) (2.0.2)
# Collecting DyNet38 (from nagisa)
#   Downloading dyNET38-2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.12/dist-packages (from DyNet38->nagisa) (3.0.12)
# Downloading nagisa-0.2.12-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (21.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.7/21.7 MB 112.2 MB/s  0:00:00
# Downloading dyNET38-2.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 144.3 MB/s  0:00:00
# Installing collected packages: DyNet38, nagisa
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nagisa]
# Successfully installed DyNet38-2.2 nagisa-0.2.12
# Collecting pymupdf
#   Downloading pymupdf-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (24 kB)
# Downloading pymupdf-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl (25.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 25.0/25.0 MB 334.7 MB/s  0:00:00
# Installing collected packages: pymupdf
# Successfully installed pymupdf-1.27.2.3
# Collecting pymupdf-layout
#   Downloading pymupdf_layout-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: PyMuPDF==1.27.2.3 in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (1.27.2.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (6.0.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (2.0.2)
# Collecting onnxruntime (from pymupdf-layout)
#   Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from pymupdf-layout) (3.6.1)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (25.12.19)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime->pymupdf-layout) (5.29.6)
# Downloading pymupdf_layout-1.27.2.3-cp310-abi3-manylinux_2_28_x86_64.whl (15.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 183.9 MB/s  0:00:00
# Downloading onnxruntime-1.26.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 221.7 MB/s  0:00:00
# Installing collected packages: onnxruntime, pymupdf-layout
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pymupdf-layout]
# Successfully installed onnxruntime-1.26.0 pymupdf-layout-1.27.2.3
# Collecting unidic
#   Downloading unidic-1.1.0.tar.gz (7.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from unidic) (2.32.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.41.1 in /usr/local/lib/python3.12/dist-packages (from unidic) (4.67.3)
# Collecting wasabi<1.0.0,>=0.6.0 (from unidic)
#   Downloading wasabi-0.10.1-py3-none-any.whl.metadata (28 kB)
# Collecting plac<2.0.0,>=1.1.3 (from unidic)
#   Downloading plac-1.4.5-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.22.0->unidic) (2026.5.20)
# Downloading plac-1.4.5-py2.py3-none-any.whl (22 kB)
# Downloading wasabi-0.10.1-py3-none-any.whl (26 kB)
# Building wheels for collected packages: unidic
#   Building wheel for unidic (pyproject.toml) ... done
#   Created wheel for unidic: filename=unidic-1.1.0-py3-none-any.whl size=7471 sha256=d083a1d8e4e720acb8c2ad739be15d51efbabf9fc4b6e7770d1868ffcff29050
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-e62f0s9d/wheels/cb/04/a2/659428f84ed1fa7257f8efb544b36043dd37a7c419e8ca711a
# Successfully built unidic
# Installing collected packages: wasabi, plac, unidic
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [unidic]
# Successfully installed plac-1.4.5 unidic-1.1.0 wasabi-0.10.1
# Collecting hangul-romanize
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl.metadata (1.2 kB)
# Downloading hangul_romanize-0.1.0-py3-none-any.whl (4.6 kB)
# Installing collected packages: hangul-romanize
# Successfully installed hangul-romanize-0.1.0
# Collecting iso639-lang
#   Downloading iso639_lang-2.6.3-py3-none-any.whl.metadata (8.4 kB)
# Downloading iso639_lang-2.6.3-py3-none-any.whl (324 kB)
# Installing collected packages: iso639-lang
# Successfully installed iso639-lang-2.6.3
# Collecting soynlp
#   Downloading soynlp-0.0.493-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: numpy>=1.12.1 in /usr/local/lib/python3.12/dist-packages (from soynlp) (2.0.2)
# Requirement already satisfied: psutil>=5.0.1 in /usr/local/lib/python3.12/dist-packages (from soynlp) (5.9.5)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from soynlp) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from soynlp) (1.6.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->soynlp) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.20.0->soynlp) (3.6.0)
# Downloading soynlp-0.0.493-py3-none-any.whl (416 kB)
# Installing collected packages: soynlp
# Successfully installed soynlp-0.0.493
# Collecting uroman
#   Downloading uroman-1.3.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: regex>=2024.5.15 in /usr/local/lib/python3.12/dist-packages (from uroman) (2025.11.3)
# Downloading uroman-1.3.1.1-py3-none-any.whl (930 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 930.7/930.7 kB 153.4 MB/s  0:00:00
# Installing collected packages: uroman
# Successfully installed uroman-1.3.1.1
# Collecting pycantonese
#   Downloading pycantonese-5.0.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.1 kB)
# Collecting rustling>=0.8.0 (from pycantonese)
#   Downloading rustling-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.7 kB)
# Downloading pycantonese-5.0.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 114.9 MB/s  0:00:00
# Downloading rustling-0.8.0-cp310-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 107.3 MB/s  0:00:00
# Installing collected packages: rustling, pycantonese
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pycantonese]
# Successfully installed pycantonese-5.0.0 rustling-0.8.0
# Collecting pypinyin
#   Downloading pypinyin-0.55.0-py2.py3-none-any.whl.metadata (12 kB)
# Downloading pypinyin-0.55.0-py2.py3-none-any.whl (840 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.2/840.2 kB 120.2 MB/s  0:00:00
# Installing collected packages: pypinyin
# Successfully installed pypinyin-0.55.0
# Collecting pythainlp
#   Downloading pythainlp-5.3.4-py3-none-any.whl.metadata (23 kB)
# Downloading pythainlp-5.3.4-py3-none-any.whl (19.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 275.6 MB/s  0:00:00
# Installing collected packages: pythainlp
# Successfully installed pythainlp-5.3.4
# Collecting pykakasi
#   Downloading pykakasi-2.3.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting jaconv (from pykakasi)
# ...
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=4.57->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (0.1.2)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.17.1->coqui-tts-trainer<0.4.0,>=0.3.0->coqui-tts==0.27.5->coqui-tts[languages]==0.27.5) (3.0.3)
# Downloading coqui_tts-0.27.5-py3-none-any.whl (862 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 862.8/862.8 kB 555.7 MB/s  0:00:00
# Downloading coqpit_config-0.2.5-py3-none-any.whl (15 kB)
# Downloading coqui_tts_trainer-0.3.3-py3-none-any.whl (56 kB)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
# Downloading bangla-0.0.6-py3-none-any.whl (8.1 kB)
# Downloading bnunicodenormalizer-0.1.7-py3-none-any.whl (23 kB)
# Downloading cutlet-0.5.0-py3-none-any.whl (11 kB)
# Downloading fugashi-1.5.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (694 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 694.9/694.9 kB 767.6 MB/s  0:00:00
# Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
# Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading python_crfsuite-0.9.12-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 513.5 MB/s  0:00:00
# Downloading ko_speech_tools-0.1.0-py3-none-any.whl (997 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.3/997.3 kB 643.9 MB/s  0:00:00
# Downloading mecab_ko-1.0.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (592 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 593.0/593.0 kB 344.4 MB/s  0:00:00
# Downloading monotonic_alignment_search-0.2.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (648 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.4/648.4 kB 698.7 MB/s  0:00:00
# Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
# Downloading spacy_pkuseg-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 321.0 MB/s  0:00:00
# Downloading mojimoji-0.0.13-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (211 kB)
# Building wheels for collected packages: bnnumerizer, gruut, gruut-ipa, gruut_lang_en, gruut_lang_de, gruut_lang_es, gruut_lang_fr, mecab-ko-dic, unidic-lite
#   Building wheel for bnnumerizer (pyproject.toml) ... done
#   Created wheel for bnnumerizer: filename=bnnumerizer-0.0.2-py3-none-any.whl size=5339 sha256=40cb26a06d457c378ffcb7c84f0c68ce046b0a6da5dcd457f5e7ae76451df9bf
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/54/a3/40/cc330c64cd0abbaf0e112d9a14ae0b835c74f560b493ecc1bb
#   Building wheel for gruut (pyproject.toml) ... done
#   Created wheel for gruut: filename=gruut-2.4.0-py3-none-any.whl size=86855 sha256=d27820a6cc2de690133a2d1102d897bb8a0abfa3c63d7fb0cf63ab7d7e194fb8
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/e6/93/9c/fbd0d8778ac586a48a20e73d2a64d882984d9501fd5e8daf24
#   Building wheel for gruut-ipa (pyproject.toml) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104963 sha256=10e2fca31c855f657f4c2edd99037bab3730be5cefec059adf42a5947ddc076a
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/66/9d/d2/d6f6eb77784f063fcd497427fd93324cebf974247984bba85b
#   Building wheel for gruut_lang_en (pyproject.toml) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.1-py3-none-any.whl size=15326899 sha256=1a15e3161d935a5683a3975dcc95ce44d244d9f2263822dda454ea03e7768f32
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/b0/ca/a4/d1a6f20e47b857313689ca1f31684102ba67cecda2acae368d
#   Building wheel for gruut_lang_de (pyproject.toml) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.1-py3-none-any.whl size=18498356 sha256=64cb14f83cee389e60e482ff7519084ee5d36311b48a4158d56e0bd55ad9caf6
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/dc/75/26/e627d52dac0253ad7d11e5b9f74d51d82e040d07432f53ad9b
#   Building wheel for gruut_lang_es (pyproject.toml) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-2.0.1-py3-none-any.whl size=32173970 sha256=517c0497a398915c7cbf4b0811594e9fa0ecb1034f1f1016470f873775adb1cb
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/6e/19/79/0a65f77c4921ae0daa8d01e5b11502a909b55bd22fa188962d
#   Building wheel for gruut_lang_fr (pyproject.toml) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968810 sha256=b54910bee44aa622999402506b72a660b16028db49854104dc48ee5a270ae20f
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/1e/91/46/0ab326f9e46bc2cc2fe2f35b0e0e6f3b8284d78efd25192d96
#   Building wheel for mecab-ko-dic (pyproject.toml) ... done
#   Created wheel for mecab-ko-dic: filename=mecab_ko_dic-1.0.0-py3-none-any.whl size=33424435 sha256=557c3a5232d948257b5745898409e1098a4a0afc070c2762c41387a32e9c207b
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/38/b6/bb/e5c73805f8318db251a0a10b4a8becfb4c4e9e49a5b892761a
#   Building wheel for unidic-lite (pyproject.toml) ... done
#   Created wheel for unidic-lite: filename=unidic_lite-1.0.8-py3-none-any.whl size=47658912 sha256=420f3aaa1e69146d8f1760f9a0328fc33d7159d340c33d13fac0ea9d4c860315
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-1xcpcs_m/wheels/5e/1f/0f/4d43887e5476d956fae828ee9b6687becd5544d68b51ed633d
# Successfully built bnnumerizer gruut gruut-ipa gruut_lang_en gruut_lang_de gruut_lang_es gruut_lang_fr mecab-ko-dic unidic-lite
# Installing collected packages: unidic-lite, mecab-ko-dic, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, bnunicodenormalizer, bnnumerizer, python-crfsuite, pysbd, num2words, monotonic-alignment-search, mojimoji, mecab-ko, ko-speech-tools, jsonlines, gruut-ipa, fugashi, coqpit-config, bangla, anyascii, spacy-pkuseg, dateparser, cutlet, gruut, coqui-tts-trainer, coqui-tts
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27/27 [coqui-tts]
# Successfully installed anyascii-0.3.3 bangla-0.0.6 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.7 coqpit-config-0.2.5 coqui-tts-0.27.5 coqui-tts-trainer-0.3.3 cutlet-0.5.0 dateparser-1.1.8 fugashi-1.5.2 gruut-2.4.0 gruut-ipa-0.13.0 gruut_lang_de-2.0.1 gruut_lang_en-2.0.1 gruut_lang_es-2.0.1 gruut_lang_fr-2.0.2 jsonlines-1.2.0 ko-speech-tools-0.1.0 mecab-ko-1.0.2 mecab-ko-dic-1.0.0 mojimoji-0.0.13 monotonic-alignment-search-0.2.1 num2words-0.5.14 pysbd-0.3.4 python-crfsuite-0.9.12 spacy-pkuseg-1.0.1 unidic-lite-1.0.8
# Collecting piper-tts==1.4.2
#   Downloading piper_tts-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Requirement already satisfied: onnxruntime<2,>=1 in /usr/local/lib/python3.12/dist-packages (from piper-tts==1.4.2) (1.26.0)
# Collecting pathvalidate<4,>=3 (from piper-tts==1.4.2)
#   Downloading pathvalidate-3.3.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1->piper-tts==1.4.2) (25.12.19)
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1->piper-tts==1.4.2) (2.4.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1->piper-tts==1.4.2) (26.2)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime<2,>=1->piper-tts==1.4.2) (5.29.6)
# Downloading piper_tts-1.4.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 317.4 MB/s  0:00:00
# Downloading pathvalidate-3.3.1-py3-none-any.whl (24 kB)
# Installing collected packages: pathvalidate, piper-tts
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [piper-tts]
# Successfully installed pathvalidate-3.3.1 piper-tts-1.4.2
# Processing ./ext/py/demucs
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: dora-search in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (0.1.12)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (0.8.2)
# Requirement already satisfied: julius in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (0.2.8)
# Requirement already satisfied: lameenc in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (1.8.2)
# Requirement already satisfied: openunmix in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (6.0.3)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (2.9.0+cu128)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (2.9.0+cu128)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from demucs==4.1.0) (4.67.3)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs==4.1.0) (2.3.0)
# Requirement already satisfied: retrying in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs==4.1.0) (1.4.2)
# Requirement already satisfied: submitit in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs==4.1.0) (1.5.4)
# Requirement already satisfied: treetable in /usr/local/lib/python3.12/dist-packages (from dora-search->demucs==4.1.0) (0.2.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (2026.4.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (1.13.1.3)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->demucs==4.1.0) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->demucs==4.1.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->demucs==4.1.0) (3.0.3)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->dora-search->demucs==4.1.0) (4.9.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openunmix->demucs==4.1.0) (2.4.6)
# Requirement already satisfied: cloudpickle>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from submitit->dora-search->demucs==4.1.0) (3.1.2)
# Building wheels for collected packages: demucs
#   Building wheel for demucs (pyproject.toml) ... done
#   Created wheel for demucs: filename=demucs-4.1.0-py3-none-any.whl size=76035 sha256=3a2a2749ce6f4ceb94536146bff966d9c6494cdf61fe2c984914e1dc5540eaeb
#   Stored in directory: /content/ebook2audiobook/run/pip-ephem-wheel-cache-9hecwtt5/wheels/4d/88/27/04af536f68017d4c7c89afad59d5b7b463eb9c7194806fe3e5
# Successfully built demucs
# Installing collected packages: demucs
# Successfully installed demucs-4.1.0
#
# All required packages are installed.
# UniDic dictionary not found or incomplete. Downloading now…
# download url: https://cotonoha-dic.s3-ap-northeast-1.amazonaws.com/unidic-3.1.0.zip
# Dictionary version: 3.1.0+2021-08-31
# Downloading UniDic v3.1.0+2021-08-31...
# unidic-3.1.0.zip: 100% 526M/526M [02:24<00:00, 3.64MB/s]
# Finished download.
# Downloaded UniDic v3.1.0+2021-08-31 to /usr/local/lib/python3.12/dist-packages/unidic/dicdir
# IPs available for connection:
# ['127.0.0.1', '::1', '172.28.0.12']
# Note: 0.0.0.0 is not the IP to connect. Instead use an IP above to connect and port 7860
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://8c66bf809b54621d76.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
#  Note: access limit time: 3 daysYour browser needs cookies enabled to resume the conversions.

# %%
from google.colab import drive
drive.mount('/content/drive')
